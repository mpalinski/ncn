# %%
d={"id": 'CY', "val": 81},{"id": 'EE', "val": 39},{"id": 'LT', "val": 53},{"id": 'BG', "val": 61},{"id": 'RO', "val": 59},{"id": 'LU', "val": 64},{"id": 'SI', "val": 48},{"id": 'HR', "val": 59}, {"id": 'AT', "val": 51}, {"id": 'BE', "val": 67}, {"id": 'CZ', "val": 56}, {"id": 'DE', "val": 59}, {"id": 'DK', "val": 50}, {"id": 'EL', "val": 63}, {"id": 'ES', "val": 65}, {"id": 'FI', "val": 62}, {"id": 'FR', "val": 72}, {"id": 'HU', "val": 55}, {"id": 'IE', "val": 75}, {"id": 'IT', "val": 66}, {"id": 'LV', "val": 50}, {"id": 'NL', "val": 48}, {"id": 'PL', "val": 54}, {"id": 'PT', "val": 77}, {"id": 'SE', "val": 33}, {"id": 'SK', "val": 51}, {"id": 'UK', "val": 73}

# %%
for i in d:
    print('{id: \"'+i['id']+'\",\n value: '+str(i['val'])+',\n},')
# Out:
# {id: "CY",
#  value: 81,
# },
# {id: "EE",
#  value: 39,
# },
# {id: "LT",
#  value: 53,
# },
# {id: "BG",
#  value: 61,
# },
# {id: "RO",
#  value: 59,
# },
# {id: "LU",
#  value: 64,
# },
# {id: "SI",
#  value: 48,
# },
# {id: "HR",
#  value: 59,
# },
# {id: "AT",
#  value: 51,
# },
# {id: "BE",
#  value: 67,
# },
# {id: "CZ",
#  value: 56,
# },
# {id: "DE",
#  value: 59,
# },
# {id: "DK",
#  value: 50,
# },
# {id: "EL",
#  value: 63,
# },
# {id: "ES",
#  value: 65,
# },
# {id: "FI",
#  value: 62,
# },
# {id: "FR",
#  value: 72,
# },
# {id: "HU",
#  value: 55,
# },
# {id: "IE",
#  value: 75,
# },
# {id: "IT",
#  value: 66,
# },
# {id: "LV",
#  value: 50,
# },
# {id: "NL",
#  value: 48,
# },
# {id: "PL",
#  value: 54,
# },
# {id: "PT",
#  value: 77,
# },
# {id: "SE",
#  value: 33,
# },
# {id: "SK",
#  value: 51,
# },
# {id: "UK",
#  value: 73,
# },

# %%
e={"id": 'CY', "val": 81},{"id": 'EE', "val": 71},{"id": 'LT', "val": 78},{"id": 'BG', "val": 48},{"id": 'RO', "val": 64},{"id": 'LU', "val": 63},{"id": 'SI', "val": 69},{"id": 'HR', "val": 74}, {"id": 'AT', "val": 67}, {"id": 'BE', "val": 65}, {"id": 'CZ', "val": 68}, {"id": 'DE', "val": 51}, {"id": 'DK', "val": 64}, {"id": 'EL', "val": 71}, {"id": 'ES', "val": 57}, {"id": 'FI', "val": 82}, {"id": 'FR', "val": 62}, {"id": 'HU', "val": 71}, {"id": 'IE', "val": 66}, {"id": 'IT', "val": 66}, {"id": 'LV', "val": 67}, {"id": 'NL', "val": 71}, {"id": 'PL', "val": 78}, {"id": 'PT', "val": 85}, {"id": 'SE', "val": 71}, {"id": 'SK', "val": 77}, {"id": 'UK', "val": 75}

# %%
for i in e:
    print('{id: \"'+i['id']+'\",\n value: '+str(i['val'])+',\n},')
# Out:
# {id: "CY",
#  value: 81,
# },
# {id: "EE",
#  value: 71,
# },
# {id: "LT",
#  value: 78,
# },
# {id: "BG",
#  value: 48,
# },
# {id: "RO",
#  value: 64,
# },
# {id: "LU",
#  value: 63,
# },
# {id: "SI",
#  value: 69,
# },
# {id: "HR",
#  value: 74,
# },
# {id: "AT",
#  value: 67,
# },
# {id: "BE",
#  value: 65,
# },
# {id: "CZ",
#  value: 68,
# },
# {id: "DE",
#  value: 51,
# },
# {id: "DK",
#  value: 64,
# },
# {id: "EL",
#  value: 71,
# },
# {id: "ES",
#  value: 57,
# },
# {id: "FI",
#  value: 82,
# },
# {id: "FR",
#  value: 62,
# },
# {id: "HU",
#  value: 71,
# },
# {id: "IE",
#  value: 66,
# },
# {id: "IT",
#  value: 66,
# },
# {id: "LV",
#  value: 67,
# },
# {id: "NL",
#  value: 71,
# },
# {id: "PL",
#  value: 78,
# },
# {id: "PT",
#  value: 85,
# },
# {id: "SE",
#  value: 71,
# },
# {id: "SK",
#  value: 77,
# },
# {id: "UK",
#  value: 75,
# },
